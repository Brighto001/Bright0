# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# LOAD MY CSV FILE INTO A DATAFRAME

# %%
df = pd.read_csv(r"c:\Users\hp\Desktop\Sirbright\healthcare_data.csv")
df.head()
# Out:
#       Sex    State History of Sugar Level in Family  Age  Glucose Sugar Level  \
# 0    Male     Abia                              Yes   33                107.0
# 1  Female    Enugu                              Yes   36                115.2
# 2    Male  Katsina                              Yes   47                107.9
# 3    Male     Kano                              Yes   58                 96.1
# 4    Male   Kaduna                               No   33                 74.8
#
#     BMI
# 0  20.3
# 1  24.3
# 2  27.7
# 3  31.1
# 4  26.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Sex                               7668 non-null   object
#  1   State                             7668 non-null   object
#  2   History of Sugar Level in Family  7668 non-null   object
#  3   Age                               7668 non-null   int64
#  4   Glucose Sugar Level               7668 non-null   float64
#  5   BMI                               7668 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 359.6+ KB

# %%
df.describe()
# Out:
#                Age  Glucose Sugar Level          BMI
# count  7668.000000          7668.000000  7668.000000
# mean     48.386802           103.939775    27.273122
# std      17.894626            22.091981     5.577000
# min      18.000000            27.800000    18.500000
# 25%      33.000000            91.100000    22.900000
# 50%      49.000000           102.500000    26.100000
# 75%      64.000000           114.400000    30.800000
# max      79.000000           298.156434    40.000000

# %%
df.head()
# Out:
#       Sex    State History of Sugar Level in Family  Age  Glucose Sugar Level  \
# 0    Male     Abia                              Yes   33                107.0
# 1  Female    Enugu                              Yes   36                115.2
# 2    Male  Katsina                              Yes   47                107.9
# 3    Male     Kano                              Yes   58                 96.1
# 4    Male   Kaduna                               No   33                 74.8
#
#     BMI
# 0  20.3
# 1  24.3
# 2  27.7
# 3  31.1
# 4  26.4

# %%
df["State"].unique()
# Out:
# array(['Abia', 'Enugu', 'Katsina', 'Kano', 'Kaduna', 'FCT', 'Ogun', 'Imo',
#        'Lagos', 'Rivers'], dtype=object)

# %%
df["Sex"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df["History of Sugar Level in Family"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# COMPARATIVE ANALYSIS: TABLES, GRAPH, VISUALIZATION

# %%
df.head()
# Out:
#       Sex    State History of Sugar Level in Family  Age  Glucose Sugar Level  \
# 0    Male     Abia                              Yes   33                107.0
# 1  Female    Enugu                              Yes   36                115.2
# 2    Male  Katsina                              Yes   47                107.9
# 3    Male     Kano                              Yes   58                 96.1
# 4    Male   Kaduna                               No   33                 74.8
#
#     BMI
# 0  20.3
# 1  24.3
# 2  27.7
# 3  31.1
# 4  26.4

# %%
plt.hist(x= df["Age"], bins= 10, edgecolor= "red")
plt.gca().set_facecolor("yellow")

# %%
df.head()
# Out:
#       Sex    State History of Sugar Level in Family  Age  Glucose Sugar Level  \
# 0    Male     Abia                              Yes   33                107.0
# 1  Female    Enugu                              Yes   36                115.2
# 2    Male  Katsina                              Yes   47                107.9
# 3    Male     Kano                              Yes   58                 96.1
# 4    Male   Kaduna                               No   33                 74.8
#
#     BMI
# 0  20.3
# 1  24.3
# 2  27.7
# 3  31.1
# 4  26.4

# %%
pd.pivot_table(df, index= "State", values= ["Glucose Sugar Level", "BMI"], aggfunc= "mean").plot(kind= "pie", subplots= True, legend= False,figsize=(15, 6))
# Out:
# array([<Axes: ylabel='BMI'>, <Axes: ylabel='Glucose Sugar Level'>],
#       dtype=object)
