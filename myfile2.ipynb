# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# LOAD CSV FILE INTO A DATAFRAME

# %%
df= pd.read_csv(r"c:\Users\hp\Desktop\Sirbright\apartment_data1.csv")
df.head()
# Out:
#   Apartment_ID                                   Location  Postal Code  \
# 0     NRAS0001    NorthEast_Ekiti State_437 Broadway Road     995056.0
# 1     NRAS0002    NorthWest_Plateau State_387 Main Street     568247.0
# 2     NRAS0003  SouthEast_Nasarawa State_247 Unity Avenue     304911.0
# 3     NRAS0004   SouthEast_Bauchi State_323 Broadway Road     938476.0
# 4     NRAS0005   NorthWest_Plateau State_493 Unity Avenue     213401.0
#
#    Number of Floors  Number of Rooms Ceiling Finish  Room Size (sq. meters)  \
# 0              12.0              8.0         Gypsum               48.130072
# 1               1.0              6.0            POP               29.288397
# 2               6.0              7.0            POP               13.122074
# 3               6.0             10.0           Wood               24.854701
# 4               7.0              1.0           Wood               39.275249
#
#    Year Built  Month Built                          Utilities Available  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Apartment_ID              10000 non-null  object
#  1   Location                  9985 non-null   object
#  2   Postal Code               9991 non-null   float64
#  3   Number of Floors          9990 non-null   float64
#  4   Number of Rooms           9987 non-null   float64
#  5   Ceiling Finish            9982 non-null   object
#  6   Room Size (sq. meters)    9986 non-null   float64
#  7   Year Built                9983 non-null   float64
#  8   Month Built               9987 non-null   float64
#  9   Utilities Available       9991 non-null   object
#  10  Price of Apartment        9987 non-null   float64
#  11  Price of Apartment (USD)  9987 non-null   float64
# dtypes: float64(8), object(4)
# memory usage: 937.6+ KB

# %%
df["Year Built"] = df["Year Built"].astype("string").str.replace(".0", "")

# %%
x = ["Year Built", "Month Built"]
for i in x:
    df[f"{i}"] = df[f"{i}"].astype("string").str.replace(".0", "")

# %%
df.head()
# Out:
#   Apartment_ID                                   Location  Postal Code  \
# 0     NRAS0001    NorthEast_Ekiti State_437 Broadway Road     995056.0
# 1     NRAS0002    NorthWest_Plateau State_387 Main Street     568247.0
# 2     NRAS0003  SouthEast_Nasarawa State_247 Unity Avenue     304911.0
# 3     NRAS0004   SouthEast_Bauchi State_323 Broadway Road     938476.0
# 4     NRAS0005   NorthWest_Plateau State_493 Unity Avenue     213401.0
#
#    Number of Floors  Number of Rooms Ceiling Finish  Room Size (sq. meters)  \
# 0              12.0              8.0         Gypsum               48.130072
# 1               1.0              6.0            POP               29.288397
# 2               6.0              7.0            POP               13.122074
# 3               6.0             10.0           Wood               24.854701
# 4               7.0              1.0           Wood               39.275249
#
#   Year Built Month Built                          Utilities Available  \
# ...

# %%
df["Price of Apartment"] = df["Price of Apartment"].astype("string").str.replace(".0", "")

# %%
df.head()
# Out:
#   Apartment_ID                                   Location  Postal Code  \
# 0     NRAS0001    NorthEast_Ekiti State_437 Broadway Road     995056.0
# 1     NRAS0002    NorthWest_Plateau State_387 Main Street     568247.0
# 2     NRAS0003  SouthEast_Nasarawa State_247 Unity Avenue     304911.0
# 3     NRAS0004   SouthEast_Bauchi State_323 Broadway Road     938476.0
# 4     NRAS0005   NorthWest_Plateau State_493 Unity Avenue     213401.0
#
#    Number of Floors  Number of Rooms Ceiling Finish  Room Size (sq. meters)  \
# 0              12.0              8.0         Gypsum               48.130072
# 1               1.0              6.0            POP               29.288397
# 2               6.0              7.0            POP               13.122074
# 3               6.0             10.0           Wood               24.854701
# 4               7.0              1.0           Wood               39.275249
#
#   Year Built Month Built                          Utilities Available  \
# ...

# %%
df["Date Built"] = df["Year Built"] + "-" + df["Month Built"]
df.head()
# Out:
#   Apartment_ID                                   Location  Postal Code  \
# 0     NRAS0001    NorthEast_Ekiti State_437 Broadway Road     995056.0
# 1     NRAS0002    NorthWest_Plateau State_387 Main Street     568247.0
# 2     NRAS0003  SouthEast_Nasarawa State_247 Unity Avenue     304911.0
# 3     NRAS0004   SouthEast_Bauchi State_323 Broadway Road     938476.0
# 4     NRAS0005   NorthWest_Plateau State_493 Unity Avenue     213401.0
#
#    Number of Floors  Number of Rooms Ceiling Finish  Room Size (sq. meters)  \
# 0              12.0              8.0         Gypsum               48.130072
# 1               1.0              6.0            POP               29.288397
# 2               6.0              7.0            POP               13.122074
# 3               6.0             10.0           Wood               24.854701
# 4               7.0              1.0           Wood               39.275249
#
#   Year Built Month Built                          Utilities Available  \
# ...

# %%
df.drop(columns= x, inplace= True)
df.head()
# Out:
#   Apartment_ID                                   Location  Postal Code  \
# 0     NRAS0001    NorthEast_Ekiti State_437 Broadway Road     995056.0
# 1     NRAS0002    NorthWest_Plateau State_387 Main Street     568247.0
# 2     NRAS0003  SouthEast_Nasarawa State_247 Unity Avenue     304911.0
# 3     NRAS0004   SouthEast_Bauchi State_323 Broadway Road     938476.0
# 4     NRAS0005   NorthWest_Plateau State_493 Unity Avenue     213401.0
#
#    Number of Floors  Number of Rooms Ceiling Finish  Room Size (sq. meters)  \
# 0              12.0              8.0         Gypsum               48.130072
# 1               1.0              6.0            POP               29.288397
# 2               6.0              7.0            POP               13.122074
# 3               6.0             10.0           Wood               24.854701
# 4               7.0              1.0           Wood               39.275249
#
#                            Utilities Available Price of Apartment  \
# ...

# %%
df["Location"].str.split("_")
# Out:
# 0         [NorthEast, Ekiti State, 437 Broadway Road]
# 1         [NorthWest, Plateau State, 387 Main Street]
# 2       [SouthEast, Nasarawa State, 247 Unity Avenue]
# 3        [SouthEast, Bauchi State, 323 Broadway Road]
# 4        [NorthWest, Plateau State, 493 Unity Avenue]
#                             ...
# 9995    [NorthCentral, Enugu State, 312 Unity Avenue]
# 9996         [NorthWest, Kebbi State, 56 Main Street]
# 9997        [NorthWest, Kano State, 435 Unity Avenue]
# 9998       [NorthEast, Ondo State, 450 Broadway Road]
# 9999          [NorthWest, Benue State, 51 SDA Street]
# Name: Location, Length: 10000, dtype: object

# %%
df["Geopolitical Zone"], df["State"]
